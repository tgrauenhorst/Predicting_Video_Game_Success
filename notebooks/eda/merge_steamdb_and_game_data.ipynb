# %% [markdown]
# # Merging Different Datasets

# %% [markdown]
# ## Preliminary

# %% [markdown]
# #### Import Modules

# %%
import pandas as pd

# %% [markdown]
# #### Set Options

# %%
pd.set_option('display.max_rows', 70) # display more rows
pd.set_option('display.max_columns', 50) # display more columns
pd.set_option('display.float_format', '{:.2f}'.format) # display numbers as decimals

# %% [markdown]
# ## Load Data

# %%
df_steamdb = pd.read_csv(r'../../data/steamdb.csv', low_memory=False)
df_game_data = pd.read_csv(r'../../data/game_data_all.csv')

# %% [markdown]
# ## Inspect Input Data

# %% [markdown]
# ### Shape

# %%
print(f'{df_steamdb.shape = }')
print(f'{df_game_data.shape = }')
# Out:
# df_steamdb.shape = (53981, 46)
# df_game_data.shape = (67571, 20)

# %% [markdown]
# ### Columns

# %%
# standardize column names
df_steamdb = df_steamdb.rename(columns={'store_url': 'steam_url'})
df_game_data = df_game_data.rename(columns={'link': 'steam_url'})

# %%
display(list(df_steamdb.columns))
# Out:
# ['sid',
#  'steam_url',
#  'store_promo_url',
#  'store_uscore',
#  'published_store',
#  'published_meta',
#  'published_stsp',
#  'published_hltb',
#  'published_igdb',
#  'image',
#  'name',
#  'description',
#  'full_price',
#  'current_price',
#  'discount',
#  'platforms',
#  'developers',
#  'publishers',
#  'languages',
#  'voiceovers',
#  'categories',
#  'genres',
#  'tags',
#  'achievements',
#  'gfq_url',
#  'gfq_difficulty',
#  'gfq_difficulty_comment',
#  'gfq_rating',
#  'gfq_rating_comment',
#  'gfq_length',
#  'gfq_length_comment',
#  'stsp_owners',
#  'stsp_mdntime',
#  'hltb_url',
#  'hltb_single',
#  'hltb_complete',
#  'meta_url',
#  'meta_score',
#  'meta_uscore',
#  'grnk_score',
#  'igdb_url',
#  'igdb_single',
#  'igdb_complete',
#  'igdb_score',
#  'igdb_uscore',
#  'igdb_popularity']

# %%
display(list(df_game_data.columns))
# Out:
# ['Unnamed: 0',
#  'game',
#  'steam_url',
#  'release',
#  'peak_players',
#  'positive_reviews',
#  'negative_reviews',
#  'total_reviews',
#  'rating',
#  'primary_genre',
#  'store_genres',
#  'publisher',
#  'developer',
#  'detected_technologies',
#  'store_asset_mod_time',
#  'review_percentage',
#  'players_right_now',
#  '24_hour_peak',
#  'all_time_peak',
#  'all_time_peak_date']

# %% [markdown]
# ### Missing Data

# %%
df_steamdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53981 entries, 0 to 53980
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sid                     53981 non-null  int64
#  1   steam_url               53981 non-null  object
#  2   store_promo_url         7546 non-null   object
#  3   store_uscore            33462 non-null  float64
#  4   published_store         53831 non-null  object
#  5   published_meta          33603 non-null  object
#  6   published_stsp          19616 non-null  object
#  7   published_hltb          25831 non-null  object
#  8   published_igdb          20965 non-null  object
#  9   image                   53981 non-null  object
#  10  name                    53981 non-null  object
#  11  description             53932 non-null  object
#  12  full_price              46817 non-null  float64
#  13  current_price           46817 non-null  float64
#  14  discount                6529 non-null   float64
#  15  platforms               53981 non-null  object
#  16  developers              53884 non-null  object
#  17  publishers              53657 non-null  object
#  18  languages               53964 non-null  object
#  19  voiceovers              24180 non-null  object
#  20  categories              53911 non-null  object
#  21  genres                  53981 non-null  object
#  22  tags                    20373 non-null  object
#  23  achievements            28716 non-null  float64
#  24  gfq_url                 32606 non-null  object
#  25  gfq_difficulty          12355 non-null  object
#  26  gfq_difficulty_comment  7214 non-null   object
#  27  gfq_rating              13491 non-null  float64
#  28  gfq_rating_comment      7915 non-null   object
#  29  gfq_length              10710 non-null  float64
#  30  gfq_length_comment      5082 non-null   object
#  31  stsp_owners             35466 non-null  float64
#  32  stsp_mdntime            9265 non-null   float64
#  33  hltb_url                26956 non-null  object
#  34  hltb_single             14767 non-null  float64
#  35  hltb_complete           12548 non-null  float64
#  36  meta_url                32588 non-null  object
#  37  meta_score              3700 non-null   float64
#  38  meta_uscore             6012 non-null   float64
#  39  grnk_score              5128 non-null   float64
#  40  igdb_url                21062 non-null  object
#  41  igdb_single             237 non-null    float64
#  42  igdb_complete           191 non-null    float64
#  43  igdb_score              4513 non-null   float64
#  44  igdb_uscore             12605 non-null  float64
#  45  igdb_popularity         21084 non-null  float64
# dtypes: float64(19), int64(1), object(26)
# memory usage: 18.9+ MB

# %%
df_game_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67571 entries, 0 to 67570
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             67571 non-null  int64
#  1   game                   67571 non-null  object
#  2   steam_url              67571 non-null  object
#  3   release                67571 non-null  object
#  4   peak_players           67571 non-null  int64
#  5   positive_reviews       67571 non-null  int64
#  6   negative_reviews       67571 non-null  int64
#  7   total_reviews          67571 non-null  int64
#  8   rating                 67571 non-null  float64
#  9   primary_genre          67561 non-null  object
#  10  store_genres           67514 non-null  object
#  11  publisher              67110 non-null  object
#  12  developer              67443 non-null  object
#  13  detected_technologies  60265 non-null  object
#  14  store_asset_mod_time   67275 non-null  object
#  15  review_percentage      47767 non-null  float64
#  16  players_right_now      67565 non-null  object
#  17  24_hour_peak           67565 non-null  object
#  18  all_time_peak          67571 non-null  int64
#  19  all_time_peak_date     67565 non-null  object
# dtypes: float64(2), int64(6), object(12)
# memory usage: 10.3+ MB

# %% [markdown]
# ### Head

# %%
display(df_steamdb.head(3).T)
# Out:
#                                                                         0  \
# sid                                                                    10
# steam_url                           https://store.steampowered.com/app/10
# store_promo_url               https://www.youtube.com/watch?v=oKC9SAF4JAc
# store_uscore                                                        97.00
# published_store                                                2000-11-01
# published_meta                                                 2000-11-08
# published_stsp                                                 2000-11-01
# published_hltb                                                 1999-06-12
# published_igdb                                                 1999-06-12
# image                   https://steamcdn-a.akamaihd.net/steam/apps/10/...
# name                                                       Counter-Strike
# description             Play the world's number 1 online action game. ...
# full_price                                                         999.00
# current_price                                                      999.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages               English,French,German,Italian,Spanish - Spain,...
# voiceovers              English,French,German,Italian,Spanish - Spain,...
# categories              Multi-player,PvP,Online PvP,Shared/Split Scree...
# genres                                                             Action
# tags                    Action,FPS,Multiplayer,Shooter,Classic,Team-Ba...
# achievements                                                          NaN
# gfq_url                 https://gamefaqs.gamespot.com/pc/429818-counte...
# gfq_difficulty                                           Just Right-Tough
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           3.90
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                          64.50
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                   15000000.00
# stsp_mdntime                                                       200.00
# hltb_url                           https://howlongtobeat.com/game?id=1953
# hltb_single                                                           NaN
# hltb_complete                                                         NaN
# meta_url                https://www.metacritic.com/game/pc/counter-str...
# meta_score                                                          88.00
# meta_uscore                                                         92.00
# grnk_score                                                            NaN
# igdb_url                        https://www.igdb.com/games/counter-strike
# igdb_single                                                           NaN
# igdb_complete                                                         NaN
# igdb_score                                                          70.00
# igdb_uscore                                                         83.00
# igdb_popularity                                                     25.74
#
#                                                                         1  \
# sid                                                                    20
# steam_url                           https://store.steampowered.com/app/20
# store_promo_url                                                       NaN
# store_uscore                                                        84.00
# published_store                                                1999-04-01
# published_meta                                                 1999-04-07
# published_stsp                                                 1999-04-01
# published_hltb                                                 1999-04-07
# published_igdb                                                 1999-04-07
# image                   https://steamcdn-a.akamaihd.net/steam/apps/20/...
# name                                                Team Fortress Classic
# description             One of the most popular online action games of...
# full_price                                                         499.00
# current_price                                                      499.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages               English,French,German,Italian,Spanish - Spain,...
# voiceovers                                                            NaN
# categories              Multi-player,PvP,Online PvP,Shared/Split Scree...
# genres                                                             Action
# tags                    Action,FPS,Multiplayer,Classic,Shooter,Class-B...
# achievements                                                          NaN
# gfq_url                 https://gamefaqs.gamespot.com/pc/562917-team-f...
# gfq_difficulty                                           Just Right-Tough
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           3.47
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                          50.60
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                    3500000.00
# stsp_mdntime                                                        20.00
# hltb_url                           https://howlongtobeat.com/game?id=9634
# hltb_single                                                           NaN
# hltb_complete                                                         NaN
# meta_url                https://www.metacritic.com/game/pc/team-fortre...
# meta_score                                                            NaN
# meta_uscore                                                         71.00
# grnk_score                                                            NaN
# igdb_url                 https://www.igdb.com/games/team-fortress-classic
# igdb_single                                                           NaN
# igdb_complete                                                         NaN
# igdb_score                                                            NaN
# igdb_uscore                                                         70.00
# igdb_popularity                                                      1.67
#
#                                                                         2
# sid                                                                    30
# steam_url                           https://store.steampowered.com/app/30
# store_promo_url               https://www.youtube.com/watch?v=j4MCo89bTWE
# store_uscore                                                        90.00
# published_store                                                2003-05-01
# published_meta                                                 2003-05-06
# published_stsp                                                 2003-05-01
# published_hltb                                                 2000-08-04
# published_igdb                                                 2003-05-01
# image                   https://steamcdn-a.akamaihd.net/steam/apps/30/...
# name                                                        Day of Defeat
# description             Enlist in an intense brand of Axis vs. Allied ...
# full_price                                                         499.00
# current_price                                                      499.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages                   English,French,German,Italian,Spanish - Spain
# voiceovers                                                            NaN
# categories                          Multi-player,Valve Anti-Cheat enabled
# genres                                                             Action
# tags                    FPS,World War II,Multiplayer,Action,Shooter,Wa...
# achievements                                                          NaN
# gfq_url                 https://gamefaqs.gamespot.com/pc/562741-day-of...
# gfq_difficulty                                           Just Right-Tough
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           3.69
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                          53.10
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                    7500000.00
# stsp_mdntime                                                        28.00
# hltb_url                           https://howlongtobeat.com/game?id=2282
# hltb_single                                                           NaN
# hltb_complete                                                         NaN
# meta_url                https://www.metacritic.com/game/pc/day-of-defe...
# meta_score                                                          79.00
# meta_uscore                                                         91.00
# grnk_score                                                            NaN
# igdb_url                         https://www.igdb.com/games/day-of-defeat
# igdb_single                                                           NaN
# igdb_complete                                                         NaN
# igdb_score                                                          71.00
# igdb_uscore                                                         76.00
# igdb_popularity                                                      1.45

# %%
display(df_game_data.head(3).T)
# Out:
#                                                 0  \
# Unnamed: 0                                      0
# game                                  Pizza Tower
# steam_url                           /app/2231450/
# release                                2023-01-26
# peak_players                                 4529
# positive_reviews                            19807
# negative_reviews                              227
# total_reviews                               20034
# rating                                      96.39
# primary_genre                          Action (1)
# store_genres               Action (1), Indie (23)
# publisher                           Tour De Pizza
# developer                           Tour De Pizza
# detected_technologies  Engine.GameMaker; SDK.FMOD
# store_asset_mod_time                   2023-01-10
# review_percentage                           98.00
# players_right_now                           3,101
# 24_hour_peak                                3,606
# all_time_peak                                4529
# all_time_peak_date                     2023-03-25
#
#                                                             1  \
# Unnamed: 0                                                  1
# game                                          Resident Evil 4
# steam_url                                       /app/2050650/
# release                                            2023-03-24
# peak_players                                           168191
# positive_reviews                                        61752
# negative_reviews                                         1616
# total_reviews                                           63368
# rating                                                  95.75
# primary_genre                                      Action (1)
# store_genres                       Action (1), Adventure (25)
# publisher                                     CAPCOM Co. Ltd.
# developer                                     CAPCOM Co. Ltd.
# detected_technologies  Engine.RE_Engine; SDK.AMD_GPU_Services
# store_asset_mod_time                               2023-03-29
# review_percentage                                       97.00
# players_right_now                                      46,289
# 24_hour_peak                                           47,164
# all_time_peak                                          168191
# all_time_peak_date                                 2023-03-25
#
#                                                                        2
# Unnamed: 0                                                             2
# game                                    The Murder of Sonic the Hedgehog
# steam_url                                                  /app/2324650/
# release                                                       2023-03-31
# peak_players                                                       15543
# positive_reviews                                                   12643
# negative_reviews                                                     213
# total_reviews                                                      12856
# rating                                                             95.54
# primary_genre                                                 Casual (4)
# store_genres           Casual (4), Free to Play (37), Indie (23), Sim...
# publisher                                                           SEGA
# developer                                                           SEGA
# detected_technologies             Engine.Unity; SDK.UnityBurst; SDK.cURL
# store_asset_mod_time                                          2023-03-24
# review_percentage                                                  98.00
# players_right_now                                                    618
# 24_hour_peak                                                         776
# all_time_peak                                                      15543
# all_time_peak_date                                            2023-03-31

# %% [markdown]
# ## Merge

# %% [markdown]
# ### Adjust Columns "steam_url"

# %%
# Are all entries in the "game_data" dataset column "steam_url" in a consistent format?
df_game_data['steam_url'].str.startswith(r'/app/').value_counts()
# Out:
# steam_url
# True    67571
# Name: count, dtype: int64

# %%
# Are all entries in the "df_steamdb" dataset column "steam_url" in a consistent format?
df_steamdb['steam_url'].str.startswith(r'https://store.steampowered.com/app/').value_counts()
# Out:
# steam_url
# True    53981
# Name: count, dtype: int64

# %%
# Adding the domain string to url
df_game_data['steam_url'] = 'https://store.steampowered.com' + df_game_data['steam_url']
df_game_data['steam_url'] = df_game_data['steam_url'].str.rstrip('/')

# %%
# sind alle Einträge in Dataset "game_data" Spalte "steam_url" in einem einheitlichen Format?
df_game_data['steam_url'].str.startswith(r'https://store.steampowered.com/app/').value_counts()
# Out:
# steam_url
# True    67571
# Name: count, dtype: int64

# %%
display(df_steamdb.head(3).T)
# Out:
#                                                                         0  \
# sid                                                                    10
# steam_url                           https://store.steampowered.com/app/10
# store_promo_url               https://www.youtube.com/watch?v=oKC9SAF4JAc
# store_uscore                                                        97.00
# published_store                                                2000-11-01
# published_meta                                                 2000-11-08
# published_stsp                                                 2000-11-01
# published_hltb                                                 1999-06-12
# published_igdb                                                 1999-06-12
# image                   https://steamcdn-a.akamaihd.net/steam/apps/10/...
# name                                                       Counter-Strike
# description             Play the world's number 1 online action game. ...
# full_price                                                         999.00
# current_price                                                      999.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages               English,French,German,Italian,Spanish - Spain,...
# voiceovers              English,French,German,Italian,Spanish - Spain,...
# categories              Multi-player,PvP,Online PvP,Shared/Split Scree...
# genres                                                             Action
# tags                    Action,FPS,Multiplayer,Shooter,Classic,Team-Ba...
# achievements                                                          NaN
# gfq_url                 https://gamefaqs.gamespot.com/pc/429818-counte...
# gfq_difficulty                                           Just Right-Tough
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           3.90
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                          64.50
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                   15000000.00
# stsp_mdntime                                                       200.00
# hltb_url                           https://howlongtobeat.com/game?id=1953
# hltb_single                                                           NaN
# hltb_complete                                                         NaN
# meta_url                https://www.metacritic.com/game/pc/counter-str...
# meta_score                                                          88.00
# meta_uscore                                                         92.00
# grnk_score                                                            NaN
# igdb_url                        https://www.igdb.com/games/counter-strike
# igdb_single                                                           NaN
# igdb_complete                                                         NaN
# igdb_score                                                          70.00
# igdb_uscore                                                         83.00
# igdb_popularity                                                     25.74
#
#                                                                         1  \
# sid                                                                    20
# steam_url                           https://store.steampowered.com/app/20
# store_promo_url                                                       NaN
# store_uscore                                                        84.00
# published_store                                                1999-04-01
# published_meta                                                 1999-04-07
# published_stsp                                                 1999-04-01
# published_hltb                                                 1999-04-07
# published_igdb                                                 1999-04-07
# image                   https://steamcdn-a.akamaihd.net/steam/apps/20/...
# name                                                Team Fortress Classic
# description             One of the most popular online action games of...
# full_price                                                         499.00
# current_price                                                      499.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages               English,French,German,Italian,Spanish - Spain,...
# voiceovers                                                            NaN
# categories              Multi-player,PvP,Online PvP,Shared/Split Scree...
# genres                                                             Action
# tags                    Action,FPS,Multiplayer,Classic,Shooter,Class-B...
# achievements                                                          NaN
# gfq_url                 https://gamefaqs.gamespot.com/pc/562917-team-f...
# gfq_difficulty                                           Just Right-Tough
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           3.47
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                          50.60
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                    3500000.00
# stsp_mdntime                                                        20.00
# hltb_url                           https://howlongtobeat.com/game?id=9634
# hltb_single                                                           NaN
# hltb_complete                                                         NaN
# meta_url                https://www.metacritic.com/game/pc/team-fortre...
# meta_score                                                            NaN
# meta_uscore                                                         71.00
# grnk_score                                                            NaN
# igdb_url                 https://www.igdb.com/games/team-fortress-classic
# igdb_single                                                           NaN
# igdb_complete                                                         NaN
# igdb_score                                                            NaN
# igdb_uscore                                                         70.00
# igdb_popularity                                                      1.67
#
#                                                                         2
# sid                                                                    30
# steam_url                           https://store.steampowered.com/app/30
# store_promo_url               https://www.youtube.com/watch?v=j4MCo89bTWE
# store_uscore                                                        90.00
# published_store                                                2003-05-01
# published_meta                                                 2003-05-06
# published_stsp                                                 2003-05-01
# published_hltb                                                 2000-08-04
# published_igdb                                                 2003-05-01
# image                   https://steamcdn-a.akamaihd.net/steam/apps/30/...
# name                                                        Day of Defeat
# description             Enlist in an intense brand of Axis vs. Allied ...
# full_price                                                         499.00
# current_price                                                      499.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages                   English,French,German,Italian,Spanish - Spain
# voiceovers                                                            NaN
# categories                          Multi-player,Valve Anti-Cheat enabled
# genres                                                             Action
# tags                    FPS,World War II,Multiplayer,Action,Shooter,Wa...
# achievements                                                          NaN
# gfq_url                 https://gamefaqs.gamespot.com/pc/562741-day-of...
# gfq_difficulty                                           Just Right-Tough
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           3.69
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                          53.10
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                    7500000.00
# stsp_mdntime                                                        28.00
# hltb_url                           https://howlongtobeat.com/game?id=2282
# hltb_single                                                           NaN
# hltb_complete                                                         NaN
# meta_url                https://www.metacritic.com/game/pc/day-of-defe...
# meta_score                                                          79.00
# meta_uscore                                                         91.00
# grnk_score                                                            NaN
# igdb_url                         https://www.igdb.com/games/day-of-defeat
# igdb_single                                                           NaN
# igdb_complete                                                         NaN
# igdb_score                                                          71.00
# igdb_uscore                                                         76.00
# igdb_popularity                                                      1.45

# %%
display(df_game_data.head(3).T)
# Out:
#                                                                 0  \
# Unnamed: 0                                                      0
# game                                                  Pizza Tower
# steam_url              https://store.steampowered.com/app/2231450
# release                                                2023-01-26
# peak_players                                                 4529
# positive_reviews                                            19807
# negative_reviews                                              227
# total_reviews                                               20034
# rating                                                      96.39
# primary_genre                                          Action (1)
# store_genres                               Action (1), Indie (23)
# publisher                                           Tour De Pizza
# developer                                           Tour De Pizza
# detected_technologies                  Engine.GameMaker; SDK.FMOD
# store_asset_mod_time                                   2023-01-10
# review_percentage                                           98.00
# players_right_now                                           3,101
# 24_hour_peak                                                3,606
# all_time_peak                                                4529
# all_time_peak_date                                     2023-03-25
#
#                                                                 1  \
# Unnamed: 0                                                      1
# game                                              Resident Evil 4
# steam_url              https://store.steampowered.com/app/2050650
# release                                                2023-03-24
# peak_players                                               168191
# positive_reviews                                            61752
# negative_reviews                                             1616
# total_reviews                                               63368
# rating                                                      95.75
# primary_genre                                          Action (1)
# store_genres                           Action (1), Adventure (25)
# publisher                                         CAPCOM Co. Ltd.
# developer                                         CAPCOM Co. Ltd.
# detected_technologies      Engine.RE_Engine; SDK.AMD_GPU_Services
# store_asset_mod_time                                   2023-03-29
# review_percentage                                           97.00
# players_right_now                                          46,289
# 24_hour_peak                                               47,164
# all_time_peak                                              168191
# all_time_peak_date                                     2023-03-25
#
#                                                                        2
# Unnamed: 0                                                             2
# game                                    The Murder of Sonic the Hedgehog
# steam_url                     https://store.steampowered.com/app/2324650
# release                                                       2023-03-31
# peak_players                                                       15543
# positive_reviews                                                   12643
# negative_reviews                                                     213
# total_reviews                                                      12856
# rating                                                             95.54
# primary_genre                                                 Casual (4)
# store_genres           Casual (4), Free to Play (37), Indie (23), Sim...
# publisher                                                           SEGA
# developer                                                           SEGA
# detected_technologies             Engine.Unity; SDK.UnityBurst; SDK.cURL
# store_asset_mod_time                                          2023-03-24
# review_percentage                                                  98.00
# players_right_now                                                    618
# 24_hour_peak                                                         776
# all_time_peak                                                      15543
# all_time_peak_date                                            2023-03-31

# %% [markdown]
# ### Merge "steamdb" and "game_data_all"

# %%
df_merge1 = pd.merge(df_steamdb, df_game_data, on='steam_url', how='inner')

# %% [markdown]
# #### Inspect Merged Data

# %%
print(f'{df_merge1.shape = }')
# Out:
# df_merge1.shape = (52560, 65)

# %%
display(df_merge1.head(3).T)
# Out:
#                                                                         0  \
# sid                                                                   360
# steam_url                          https://store.steampowered.com/app/360
# store_promo_url                                                       NaN
# store_uscore                                                        76.00
# published_store                                                2006-05-01
# published_meta                                                 2006-05-01
# published_stsp                                                 2006-05-01
# published_hltb                                                 2005-07-02
# published_igdb                                                 2006-05-01
# image                   https://steamcdn-a.akamaihd.net/steam/apps/360...
# name                                         Half-Life Deathmatch: Source
# description             Half-Life Deathmatch: Source is a recreation o...
# full_price                                                         999.00
# current_price                                                      999.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages                                                         English
# voiceovers                                                            NaN
# categories                          Multi-player,Valve Anti-Cheat enabled
# genres                                                             Action
# tags                    Action,FPS,Multiplayer,Sci-fi,Shooter,First-Pe...
# achievements                                                          NaN
# gfq_url                 https://gamefaqs.gamespot.com/pc/782057-half-l...
# gfq_difficulty                                                 Just Right
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           3.35
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                          21.50
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                   15000000.00
# stsp_mdntime                                                        37.00
# hltb_url                           https://howlongtobeat.com/game?id=4253
# hltb_single                                                           NaN
# hltb_complete                                                         NaN
# meta_url                https://www.metacritic.com/game/pc/half-life-d...
# meta_score                                                            NaN
# meta_uscore                                                         53.00
# grnk_score                                                            NaN
# igdb_url                https://www.igdb.com/games/half-life-deathmatc...
# igdb_single                                                           NaN
# igdb_complete                                                         NaN
# igdb_score                                                            NaN
# igdb_uscore                                                         60.00
# igdb_popularity                                                      1.00
# Unnamed: 0                                                          67555
# game                                         Half-Life Deathmatch: Source
# release                                                        2006-05-01
# peak_players                                                           79
# positive_reviews                                                     2646
# negative_reviews                                                      919
# total_reviews                                                        3565
# rating                                                              72.16
# primary_genre                                                  Action (1)
# store_genres                                                   Action (1)
# publisher                                                           Valve
# developer                                                           Valve
# detected_technologies   Engine.Source; SDK.Bink_Video; SDK.Miles_Sound...
# store_asset_mod_time                                           2019-08-31
# review_percentage                                                   74.00
# players_right_now                                                      10
# 24_hour_peak                                                           25
# all_time_peak                                                          79
# all_time_peak_date                                             2018-05-25
#
#                                                                         1  \
# sid                                                                   380
# steam_url                          https://store.steampowered.com/app/380
# store_promo_url               https://www.youtube.com/watch?v=DL_mPw7KEU8
# store_uscore                                                        95.00
# published_store                                                2006-06-01
# published_meta                                                 2006-06-01
# published_stsp                                                 2006-06-01
# published_hltb                                                 2006-06-01
# published_igdb                                                 2006-06-01
# image                   https://steamcdn-a.akamaihd.net/steam/apps/380...
# name                                             Half-Life 2: Episode One
# description             Half-Life 2 has sold over 4 million copies wor...
# full_price                                                         799.00
# current_price                                                      799.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages               English,French,German,Italian,Korean,Spanish -...
# voiceovers              English,French,German,Italian,Korean,Spanish -...
# categories              Single-player,Steam Achievements,Captions avai...
# genres                                                             Action
# tags                    FPS,Action,Sci-fi,Singleplayer,First-Person,St...
# achievements                                                        13.00
# gfq_url                 https://gamefaqs.gamespot.com/pc/927314-half-l...
# gfq_difficulty                                                 Just Right
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           4.03
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                           9.60
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                    7500000.00
# stsp_mdntime                                                       180.00
# hltb_url                           https://howlongtobeat.com/game?id=4250
# hltb_single                                                          4.00
# hltb_complete                                                        5.00
# meta_url                https://www.metacritic.com/game/pc/half-life-2...
# meta_score                                                          87.00
# meta_uscore                                                         86.00
# grnk_score                                                            NaN
# igdb_url                https://www.igdb.com/games/half-life-2-episode...
# igdb_single                                                          6.00
# igdb_complete                                                       12.00
# igdb_score                                                          87.00
# igdb_uscore                                                         84.00
# igdb_popularity                                                      4.79
# Unnamed: 0                                                          67511
# game                                             Half-Life 2: Episode One
# release                                                        2006-06-01
# peak_players                                                         1132
# positive_reviews                                                    23472
# negative_reviews                                                     1042
# total_reviews                                                       24514
# rating                                                              93.57
# primary_genre                                                  Action (1)
# store_genres                                                   Action (1)
# publisher                                                           Valve
# developer                                                           Valve
# detected_technologies   Engine.Source; SDK.Bink_Video; SDK.CEF; SDK.Mi...
# store_asset_mod_time                                           2022-10-26
# review_percentage                                                   95.00
# players_right_now                                                     117
# 24_hour_peak                                                          261
# all_time_peak                                                        1132
# all_time_peak_date                                             2020-03-29
#
#                                                                         2
# sid                                                                   400
# steam_url                          https://store.steampowered.com/app/400
# store_promo_url               https://www.youtube.com/watch?v=nA9ChSA6wV4
# store_uscore                                                        98.00
# published_store                                                2007-10-10
# published_meta                                                 2007-10-10
# published_stsp                                                 2007-10-10
# published_hltb                                                 2007-10-09
# published_igdb                                                 2007-10-09
# image                   https://steamcdn-a.akamaihd.net/steam/apps/400...
# name                                                               Portal
# description             <p>Portal&trade; is a new single player game f...
# full_price                                                         999.00
# current_price                                                      999.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages               English,French,German,Russian,Danish,Dutch,Fin...
# voiceovers              English,French,German,Russian,Spanish - Spain,...
# categories              Single-player,Steam Achievements,Captions avai...
# genres                                                             Action
# tags                    Puzzle,First-Person,Singleplayer,Sci-fi,Comedy...
# achievements                                                        15.00
# gfq_url                 https://gamefaqs.gamespot.com/pc/934386-portal...
# gfq_difficulty                                                 Just Right
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           4.33
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                           9.00
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                    7500000.00
# stsp_mdntime                                                       189.00
# hltb_url                           https://howlongtobeat.com/game?id=7230
# hltb_single                                                          3.00
# hltb_complete                                                        9.00
# meta_url                https://www.metacritic.com/game/pc/portal?ftag...
# meta_score                                                          90.00
# meta_uscore                                                         92.00
# grnk_score                                                            NaN
# igdb_url                                https://www.igdb.com/games/portal
# igdb_single                                                          4.00
# igdb_complete                                                        6.00
# igdb_score                                                          80.00
# igdb_uscore                                                         88.00
# igdb_popularity                                                     14.37
# Unnamed: 0                                                          67407
# game                                                               Portal
# release                                                        2007-10-10
# peak_players                                                        20672
# positive_reviews                                                   126704
# negative_reviews                                                     1934
# total_reviews                                                      128638
# rating                                                              97.09
# primary_genre                                                  Action (1)
# store_genres                                                   Action (1)
# publisher                                                           Valve
# developer                                                           Valve
# detected_technologies   Engine.Source; SDK.Bink_Video; SDK.CEF; SDK.Mi...
# store_asset_mod_time                                           2023-04-28
# review_percentage                                                   98.00
# players_right_now                                                     457
# 24_hour_peak                                                          879
# all_time_peak                                                       20672
# all_time_peak_date                                             2010-05-14

# %%
display(list(df_merge1.columns))
# Out:
# ['sid',
#  'steam_url',
#  'store_promo_url',
#  'store_uscore',
#  'published_store',
#  'published_meta',
#  'published_stsp',
#  'published_hltb',
#  'published_igdb',
#  'image',
#  'name',
#  'description',
#  'full_price',
#  'current_price',
#  'discount',
#  'platforms',
#  'developers',
#  'publishers',
#  'languages',
#  'voiceovers',
#  'categories',
#  'genres',
#  'tags',
#  'achievements',
#  'gfq_url',
#  'gfq_difficulty',
#  'gfq_difficulty_comment',
#  'gfq_rating',
#  'gfq_rating_comment',
#  'gfq_length',
#  'gfq_length_comment',
#  'stsp_owners',
#  'stsp_mdntime',
#  'hltb_url',
#  'hltb_single',
#  'hltb_complete',
#  'meta_url',
#  'meta_score',
#  'meta_uscore',
#  'grnk_score',
#  'igdb_url',
#  'igdb_single',
#  'igdb_complete',
#  'igdb_score',
#  'igdb_uscore',
#  'igdb_popularity',
#  'Unnamed: 0',
#  'game',
#  'release',
#  'peak_players',
#  'positive_reviews',
#  'negative_reviews',
#  'total_reviews',
#  'rating',
#  'primary_genre',
#  'store_genres',
#  'publisher',
#  'developer',
#  'detected_technologies',
#  'store_asset_mod_time',
#  'review_percentage',
#  'players_right_now',
#  '24_hour_peak',
#  'all_time_peak',
#  'all_time_peak_date']

# %%
df_merge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52560 entries, 0 to 52559
# Data columns (total 65 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sid                     52560 non-null  int64
#  1   steam_url               52560 non-null  object
#  2   store_promo_url         7353 non-null   object
#  3   store_uscore            33350 non-null  float64
#  4   published_store         52470 non-null  object
#  5   published_meta          32834 non-null  object
#  6   published_stsp          19209 non-null  object
#  7   published_hltb          25798 non-null  object
#  8   published_igdb          20666 non-null  object
#  9   image                   52560 non-null  object
#  10  name                    52560 non-null  object
#  11  description             52529 non-null  object
#  12  full_price              45460 non-null  float64
#  13  current_price           45460 non-null  float64
#  14  discount                6465 non-null   float64
#  15  platforms               52560 non-null  object
#  16  developers              52473 non-null  object
#  17  publishers              52237 non-null  object
#  18  languages               52549 non-null  object
#  19  voiceovers              23636 non-null  object
#  20  categories              52517 non-null  object
#  21  genres                  52560 non-null  object
#  22  tags                    20178 non-null  object
#  23  achievements            28516 non-null  float64
#  24  gfq_url                 31868 non-null  object
#  25  gfq_difficulty          12034 non-null  object
#  26  gfq_difficulty_comment  6869 non-null   object
#  27  gfq_rating              13179 non-null  float64
#  28  gfq_rating_comment      7556 non-null   object
#  29  gfq_length              10368 non-null  float64
#  30  gfq_length_comment      4773 non-null   object
#  31  stsp_owners             34590 non-null  float64
#  32  stsp_mdntime            9024 non-null   float64
#  33  hltb_url                26936 non-null  object
#  34  hltb_single             14598 non-null  float64
#  35  hltb_complete           12418 non-null  float64
#  36  meta_url                31842 non-null  object
#  37  meta_score              3452 non-null   float64
#  38  meta_uscore             5666 non-null   float64
#  39  grnk_score              4876 non-null   float64
#  40  igdb_url                20769 non-null  object
#  41  igdb_single             215 non-null    float64
#  42  igdb_complete           166 non-null    float64
#  43  igdb_score              4313 non-null   float64
#  44  igdb_uscore             12345 non-null  float64
#  45  igdb_popularity         20789 non-null  float64
#  46  Unnamed: 0              52560 non-null  int64
#  47  game                    52560 non-null  object
#  48  release                 52560 non-null  object
#  49  peak_players            52560 non-null  int64
#  50  positive_reviews        52560 non-null  int64
#  51  negative_reviews        52560 non-null  int64
#  52  total_reviews           52560 non-null  int64
#  53  rating                  52560 non-null  float64
#  54  primary_genre           52553 non-null  object
#  55  store_genres            52538 non-null  object
#  56  publisher               52155 non-null  object
#  57  developer               52442 non-null  object
#  58  detected_technologies   47172 non-null  object
#  59  store_asset_mod_time    52280 non-null  object
#  60  review_percentage       39105 non-null  float64
#  61  players_right_now       52559 non-null  object
#  62  24_hour_peak            52559 non-null  object
#  63  all_time_peak           52560 non-null  int64
#  64  all_time_peak_date      52559 non-null  object
# dtypes: float64(21), int64(7), object(37)
# memory usage: 26.1+ MB

# %%
display(df_merge1.head(3).T)
# Out:
#                                                                         0  \
# sid                                                                   360
# steam_url                          https://store.steampowered.com/app/360
# store_promo_url                                                       NaN
# store_uscore                                                        76.00
# published_store                                                2006-05-01
# published_meta                                                 2006-05-01
# published_stsp                                                 2006-05-01
# published_hltb                                                 2005-07-02
# published_igdb                                                 2006-05-01
# image                   https://steamcdn-a.akamaihd.net/steam/apps/360...
# name                                         Half-Life Deathmatch: Source
# description             Half-Life Deathmatch: Source is a recreation o...
# full_price                                                         999.00
# current_price                                                      999.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages                                                         English
# voiceovers                                                            NaN
# categories                          Multi-player,Valve Anti-Cheat enabled
# genres                                                             Action
# tags                    Action,FPS,Multiplayer,Sci-fi,Shooter,First-Pe...
# achievements                                                          NaN
# gfq_url                 https://gamefaqs.gamespot.com/pc/782057-half-l...
# gfq_difficulty                                                 Just Right
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           3.35
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                          21.50
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                   15000000.00
# stsp_mdntime                                                        37.00
# hltb_url                           https://howlongtobeat.com/game?id=4253
# hltb_single                                                           NaN
# hltb_complete                                                         NaN
# meta_url                https://www.metacritic.com/game/pc/half-life-d...
# meta_score                                                            NaN
# meta_uscore                                                         53.00
# grnk_score                                                            NaN
# igdb_url                https://www.igdb.com/games/half-life-deathmatc...
# igdb_single                                                           NaN
# igdb_complete                                                         NaN
# igdb_score                                                            NaN
# igdb_uscore                                                         60.00
# igdb_popularity                                                      1.00
# Unnamed: 0                                                          67555
# game                                         Half-Life Deathmatch: Source
# release                                                        2006-05-01
# peak_players                                                           79
# positive_reviews                                                     2646
# negative_reviews                                                      919
# total_reviews                                                        3565
# rating                                                              72.16
# primary_genre                                                  Action (1)
# store_genres                                                   Action (1)
# publisher                                                           Valve
# developer                                                           Valve
# detected_technologies   Engine.Source; SDK.Bink_Video; SDK.Miles_Sound...
# store_asset_mod_time                                           2019-08-31
# review_percentage                                                   74.00
# players_right_now                                                      10
# 24_hour_peak                                                           25
# all_time_peak                                                          79
# all_time_peak_date                                             2018-05-25
#
#                                                                         1  \
# sid                                                                   380
# steam_url                          https://store.steampowered.com/app/380
# store_promo_url               https://www.youtube.com/watch?v=DL_mPw7KEU8
# store_uscore                                                        95.00
# published_store                                                2006-06-01
# published_meta                                                 2006-06-01
# published_stsp                                                 2006-06-01
# published_hltb                                                 2006-06-01
# published_igdb                                                 2006-06-01
# image                   https://steamcdn-a.akamaihd.net/steam/apps/380...
# name                                             Half-Life 2: Episode One
# description             Half-Life 2 has sold over 4 million copies wor...
# full_price                                                         799.00
# current_price                                                      799.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages               English,French,German,Italian,Korean,Spanish -...
# voiceovers              English,French,German,Italian,Korean,Spanish -...
# categories              Single-player,Steam Achievements,Captions avai...
# genres                                                             Action
# tags                    FPS,Action,Sci-fi,Singleplayer,First-Person,St...
# achievements                                                        13.00
# gfq_url                 https://gamefaqs.gamespot.com/pc/927314-half-l...
# gfq_difficulty                                                 Just Right
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           4.03
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                           9.60
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                    7500000.00
# stsp_mdntime                                                       180.00
# hltb_url                           https://howlongtobeat.com/game?id=4250
# hltb_single                                                          4.00
# hltb_complete                                                        5.00
# meta_url                https://www.metacritic.com/game/pc/half-life-2...
# meta_score                                                          87.00
# meta_uscore                                                         86.00
# grnk_score                                                            NaN
# igdb_url                https://www.igdb.com/games/half-life-2-episode...
# igdb_single                                                          6.00
# igdb_complete                                                       12.00
# igdb_score                                                          87.00
# igdb_uscore                                                         84.00
# igdb_popularity                                                      4.79
# Unnamed: 0                                                          67511
# game                                             Half-Life 2: Episode One
# release                                                        2006-06-01
# peak_players                                                         1132
# positive_reviews                                                    23472
# negative_reviews                                                     1042
# total_reviews                                                       24514
# rating                                                              93.57
# primary_genre                                                  Action (1)
# store_genres                                                   Action (1)
# publisher                                                           Valve
# developer                                                           Valve
# detected_technologies   Engine.Source; SDK.Bink_Video; SDK.CEF; SDK.Mi...
# store_asset_mod_time                                           2022-10-26
# review_percentage                                                   95.00
# players_right_now                                                     117
# 24_hour_peak                                                          261
# all_time_peak                                                        1132
# all_time_peak_date                                             2020-03-29
#
#                                                                         2
# sid                                                                   400
# steam_url                          https://store.steampowered.com/app/400
# store_promo_url               https://www.youtube.com/watch?v=nA9ChSA6wV4
# store_uscore                                                        98.00
# published_store                                                2007-10-10
# published_meta                                                 2007-10-10
# published_stsp                                                 2007-10-10
# published_hltb                                                 2007-10-09
# published_igdb                                                 2007-10-09
# image                   https://steamcdn-a.akamaihd.net/steam/apps/400...
# name                                                               Portal
# description             <p>Portal&trade; is a new single player game f...
# full_price                                                         999.00
# current_price                                                      999.00
# discount                                                              NaN
# platforms                                                     WIN,MAC,LNX
# developers                                                          Valve
# publishers                                                          Valve
# languages               English,French,German,Russian,Danish,Dutch,Fin...
# voiceovers              English,French,German,Russian,Spanish - Spain,...
# categories              Single-player,Steam Achievements,Captions avai...
# genres                                                             Action
# tags                    Puzzle,First-Person,Singleplayer,Sci-fi,Comedy...
# achievements                                                        15.00
# gfq_url                 https://gamefaqs.gamespot.com/pc/934386-portal...
# gfq_difficulty                                                 Just Right
# gfq_difficulty_comment  <a href="/games/rankings?platform=19&amp;genre...
# gfq_rating                                                           4.33
# gfq_rating_comment      <a href="/games/rankings?platform=19&amp;genre...
# gfq_length                                                           9.00
# gfq_length_comment      <a href="/games/rankings?platform=19&amp;genre...
# stsp_owners                                                    7500000.00
# stsp_mdntime                                                       189.00
# hltb_url                           https://howlongtobeat.com/game?id=7230
# hltb_single                                                          3.00
# hltb_complete                                                        9.00
# meta_url                https://www.metacritic.com/game/pc/portal?ftag...
# meta_score                                                          90.00
# meta_uscore                                                         92.00
# grnk_score                                                            NaN
# igdb_url                                https://www.igdb.com/games/portal
# igdb_single                                                          4.00
# igdb_complete                                                        6.00
# igdb_score                                                          80.00
# igdb_uscore                                                         88.00
# igdb_popularity                                                     14.37
# Unnamed: 0                                                          67407
# game                                                               Portal
# release                                                        2007-10-10
# peak_players                                                        20672
# positive_reviews                                                   126704
# negative_reviews                                                     1934
# total_reviews                                                      128638
# rating                                                              97.09
# primary_genre                                                  Action (1)
# store_genres                                                   Action (1)
# publisher                                                           Valve
# developer                                                           Valve
# detected_technologies   Engine.Source; SDK.Bink_Video; SDK.CEF; SDK.Mi...
# store_asset_mod_time                                           2023-04-28
# review_percentage                                                   98.00
# players_right_now                                                     457
# 24_hour_peak                                                          879
# all_time_peak                                                       20672
# all_time_peak_date                                             2010-05-14
