# %% [markdown]
# # EDA Steam Game Data

# %% [markdown]
# ## Preliminary

# %% [markdown]
# ### Import Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set Options

# %%
pd.set_option('display.max_rows', 70) # display more rows
pd.set_option('display.max_columns', 50) # display more columns
pd.set_option('display.float_format', '{:.2f}'.format) # display numbers as decimals

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('../../data/game_data_all.csv', index_col=0)

# %% [markdown]
# ## Inspect Data

# %%
df.shape
# Out:
# (67571, 19)

# %%
df.head(3).T
# Out:
#                                                 0  \
# game                                  Pizza Tower
# link                                /app/2231450/
# release                                2023-01-26
# peak_players                                 4529
# positive_reviews                            19807
# negative_reviews                              227
# total_reviews                               20034
# rating                                      96.39
# primary_genre                          Action (1)
# store_genres               Action (1), Indie (23)
# publisher                           Tour De Pizza
# developer                           Tour De Pizza
# detected_technologies  Engine.GameMaker; SDK.FMOD
# store_asset_mod_time                   2023-01-10
# review_percentage                           98.00
# players_right_now                           3,101
# 24_hour_peak                                3,606
# all_time_peak                                4529
# all_time_peak_date                     2023-03-25
#
#                                                             1  \
# game                                          Resident Evil 4
# link                                            /app/2050650/
# release                                            2023-03-24
# peak_players                                           168191
# positive_reviews                                        61752
# negative_reviews                                         1616
# total_reviews                                           63368
# rating                                                  95.75
# primary_genre                                      Action (1)
# store_genres                       Action (1), Adventure (25)
# publisher                                     CAPCOM Co. Ltd.
# developer                                     CAPCOM Co. Ltd.
# detected_technologies  Engine.RE_Engine; SDK.AMD_GPU_Services
# store_asset_mod_time                               2023-03-29
# review_percentage                                       97.00
# players_right_now                                      46,289
# 24_hour_peak                                           47,164
# all_time_peak                                          168191
# all_time_peak_date                                 2023-03-25
#
#                                                                        2
# game                                    The Murder of Sonic the Hedgehog
# link                                                       /app/2324650/
# release                                                       2023-03-31
# peak_players                                                       15543
# positive_reviews                                                   12643
# negative_reviews                                                     213
# total_reviews                                                      12856
# rating                                                             95.54
# primary_genre                                                 Casual (4)
# store_genres           Casual (4), Free to Play (37), Indie (23), Sim...
# publisher                                                           SEGA
# developer                                                           SEGA
# detected_technologies             Engine.Unity; SDK.UnityBurst; SDK.cURL
# store_asset_mod_time                                          2023-03-24
# review_percentage                                                  98.00
# players_right_now                                                    618
# 24_hour_peak                                                         776
# all_time_peak                                                      15543
# all_time_peak_date                                            2023-03-31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67571 entries, 0 to 67570
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             67571 non-null  int64
#  1   game                   67571 non-null  object
#  2   link                   67571 non-null  object
#  3   release                67571 non-null  object
#  4   peak_players           67571 non-null  int64
#  5   positive_reviews       67571 non-null  int64
#  6   negative_reviews       67571 non-null  int64
#  7   total_reviews          67571 non-null  int64
#  8   rating                 67571 non-null  float64
#  9   primary_genre          67561 non-null  object
#  10  store_genres           67514 non-null  object
#  11  publisher              67110 non-null  object
#  12  developer              67443 non-null  object
#  13  detected_technologies  60265 non-null  object
#  14  store_asset_mod_time   67275 non-null  object
#  15  review_percentage      47767 non-null  float64
#  16  players_right_now      67565 non-null  object
#  17  24_hour_peak           67565 non-null  object
#  18  all_time_peak          67571 non-null  int64
#  19  all_time_peak_date     67565 non-null  object
# dtypes: float64(2), int64(6), object(12)
# memory usage: 10.3+ MB

# %%
df.describe(include='all').T
# Out:
#                          count unique                     top   freq     mean  \
# Unnamed: 0            67571.00    NaN                     NaN    NaN 33785.00
# game                     67571  65948                   Alone     36      NaN
# link                     67571  66427           /app/1835250/      6      NaN
# release                  67571   4023              2023-03-31    129      NaN
# peak_players          67571.00    NaN                     NaN    NaN   952.87
# positive_reviews      67571.00    NaN                     NaN    NaN  1273.53
# negative_reviews      67571.00    NaN                     NaN    NaN   216.89
# total_reviews         67571.00    NaN                     NaN    NaN  1490.42
# rating                67571.00    NaN                     NaN    NaN    65.29
# primary_genre            67561     28              Indie (23)  17862      NaN
# store_genres             67514   1880  Casual (4), Indie (23)   4047      NaN
# publisher                67110  34224          Big Fish Games    433      NaN
# developer                67443  39395         Choice of Games    150      NaN
# detected_technologies    60265   3468            Engine.Unity  16025      NaN
# store_asset_mod_time     67275   3566              2022-10-29   1005      NaN
# review_percentage     47767.00    NaN                     NaN    NaN    74.84
# players_right_now        67565   1041                       0  52713      NaN
# 24_hour_peak             67565   1236                       0  33747      NaN
# all_time_peak         67571.00    NaN                     NaN    NaN   962.99
# all_time_peak_date       67565   3688              2019-07-03    212      NaN
#
#                            std   min      25%      50%      75%        max
# Unnamed: 0            19506.21  0.00 16892.50 33785.00 50677.50   67570.00
# game                       NaN   NaN      NaN      NaN      NaN        NaN
# link                       NaN   NaN      NaN      NaN      NaN        NaN
# release                    NaN   NaN      NaN      NaN      NaN        NaN
# peak_players          19790.93  0.00     3.00     7.00    46.00 3257248.00
# positive_reviews      29551.63  0.00     5.00    19.00    99.00 6307931.00
# negative_reviews       5434.96  0.00     1.00     6.00    29.00  927317.00
# total_reviews         34009.23  1.00     7.00    26.00   132.00 7117776.00
# rating                   14.06 15.09    56.53    66.76    75.64      97.54
# primary_genre              NaN   NaN      NaN      NaN      NaN        NaN
# store_genres               NaN   NaN      NaN      NaN      NaN        NaN
# publisher                  NaN   NaN      NaN      NaN      NaN        NaN
# developer                  NaN   NaN      NaN      NaN      NaN        NaN
# detected_technologies      NaN   NaN      NaN      NaN      NaN        NaN
# store_asset_mod_time       NaN   NaN      NaN      NaN      NaN        NaN
# review_percentage        18.76  0.00    64.00    79.00    90.00     100.00
# players_right_now          NaN   NaN      NaN      NaN      NaN        NaN
# 24_hour_peak               NaN   NaN      NaN      NaN      NaN        NaN
# all_time_peak         20178.69  0.00     3.00     7.00    47.00 3257248.00
# all_time_peak_date         NaN   NaN      NaN      NaN      NaN        NaN

# %% [markdown]
# ## Format Data

# %% [markdown]
# ### Set Datetime Format

# %%
df['release'] = pd.to_datetime(df['release'])
df['all_time_peak_date'] = pd.to_datetime(df['all_time_peak_date'])

# %% [markdown]
# ### Check Formatted Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67571 entries, 0 to 67570
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   game                   67571 non-null  object
#  1   link                   67571 non-null  object
#  2   release                67571 non-null  datetime64[ns]
#  3   peak_players           67571 non-null  int64
#  4   positive_reviews       67571 non-null  int64
#  5   negative_reviews       67571 non-null  int64
#  6   total_reviews          67571 non-null  int64
#  7   rating                 67571 non-null  float64
#  8   primary_genre          67561 non-null  object
#  9   store_genres           67514 non-null  object
#  10  publisher              67110 non-null  object
#  11  developer              67443 non-null  object
#  12  detected_technologies  60265 non-null  object
#  13  store_asset_mod_time   67275 non-null  object
#  14  review_percentage      47767 non-null  float64
#  15  players_right_now      67565 non-null  object
#  16  24_hour_peak           67565 non-null  object
#  17  all_time_peak          67571 non-null  int64
#  18  all_time_peak_date     67565 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(5), object(10)
# memory usage: 10.3+ MB
